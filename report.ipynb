# %%
# %pylab inline
import seaborn as sns
import pandas as pd
import haversine as hs
from matplotlib import rcParams
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
#source : https://www.kaggle.com/datasets/johnny1994/execution-data-in-us
data = pd.read_csv("./data/execution-data.csv")
data
# Out:
#      Execution Volunteer  Number of Victims Juvenile First Name   Last Name  \
# 0                    yes                  1       no       Gary     Gilmore
# 1                     no                  1       no       John  Spenkelink
# 2                    yes                  1       no      Jesse      Bishop
# 3                    yes                  4       no     Steven        Judy
# 4                    yes                  1       no      Frank     Coppola
# ...                  ...                ...      ...        ...         ...
# 1556                  no                  1       no     Kevin      Johnson
# 1557                  no                  1       no     Thomas       Edwin
# 1558                  no                  1       no     Amber   McLaughlin
# 1559                  no                  1       no   \tRobert      Fratta
# 1560                  no                  2       no    \tScott    Eizember
#
# ...

# %%
data["Triplekill or more"] = data["Number of Victims"] >= 3
gb_mean_KillStreak = data.groupby("Sex")["Triplekill or more"].mean()
sns.barplot(x = gb_mean_KillStreak.index, y = gb_mean_KillStreak.values*100 )
plt.ylabel("Average of triplekill or more (%)")
plt.xlabel("Sexe")
# Out:
# Text(0.5, 0, 'Sexe')

# %% [markdown]
# On peut voir ci-dessus que les hommes ont 10% de chance
